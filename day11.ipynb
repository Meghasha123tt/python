# %%
import cv2

import matplotlib.pyplot as plt

# %%
vid=cv2.VideoCapture(0)

# %%
type(vid)
# Out:
# cv2.VideoCapture

# %%
vid.isOpened()
# Out:
# True

# %%
k=vid.read()

# %%
type(k)
# Out:
# tuple

# %%
k
# Out:
# (True,
#  array([[[ 0,  4, 47],
#          [ 0,  0, 51],
#          [ 0,  0, 55],
#          ...,
#          [54, 54, 80],
#          [40, 42, 63],
#          [51, 53, 73]],
#
#         [[ 0,  2, 45],
#          [ 0,  2, 45],
#          [ 0,  2, 45],
#          ...,
#          [53, 54, 79],
#          [34, 36, 59],
#          [51, 52, 75]],
#
#         [[ 0,  2, 45],
#          [ 0,  3, 40],
#          [ 0,  2, 33],
#          ...,
#          [37, 39, 66],
#          [29, 29, 56],
#          [51, 51, 79]],
#
#         ...,
#
#         [[ 6,  8, 37],
#          [ 2,  9, 36],
#          [ 0,  9, 36],
#          ...,
#          [ 8, 12, 27],
#          [ 8, 14, 27],
#          [ 8, 14, 27]],
#
#         [[ 0, 11, 35],
#          [ 0, 11, 36],
#          [ 1, 13, 39],
#          ...,
#          [ 2, 12, 34],
#          [ 0, 13, 34],
#          [ 0, 16, 37]],
#
#         [[ 0, 14, 40],
#          [ 5, 13, 42],
#          [15, 17, 48],
#          ...,
#          [ 2, 11, 33],
# ...

# %%
flag, img=vid.read()

# %%
if flag:
    plt.imshow(img)

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
if flag:
    plt.imshow(img[:,:,::-1])

# %%
for i in range(1000):
    flag,img=vid.read()
    if flag:
         cv2.imshow('Preview',img)
         cv2.waitKey(1)
