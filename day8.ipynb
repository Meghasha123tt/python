# %%
a =4

# %%
# !pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.8 MB 1.4 MB/s eta 0:00:11
#      --------------------------------------- 0.1/14.8 MB 825.8 kB/s eta 0:00:18
#      --------------------------------------- 0.1/14.8 MB 880.9 kB/s eta 0:00:17
#      --------------------------------------- 0.1/14.8 MB 853.3 kB/s eta 0:00:18
#      --------------------------------------- 0.2/14.8 MB 833.5 kB/s eta 0:00:18
#       -------------------------------------- 0.2/14.8 MB 811.5 kB/s eta 0:00:19
#       -------------------------------------- 0.3/14.8 MB 999.9 kB/s eta 0:00:15
#       --------------------------------------- 0.4/14.8 MB 1.0 MB/s eta 0:00:14
#      - -------------------------------------- 0.5/14.8 MB 1.2 MB/s eta 0:00:13
#      - -------------------------------------- 0.5/14.8 MB 1.2 MB/s eta 0:00:12
#      - -------------------------------------- 0.6/14.8 MB 1.3 MB/s eta 0:00:12
# ...

# %%
import numpy as np

# %%
b=np.array([[6,7,2],[2,3,4]])
b
# Out:
# array([[6, 7, 2],
#        [2, 3, 4]])

# %%
b.shape
# Out:
# (2, 3)

# %%
s=np.array([[4,40],[3,34],[2,55]])
s
# Out:
# array([[ 4, 40],
#        [ 3, 34],
#        [ 2, 55]])

# %%
s.shape
# Out:
# (3, 2)

# %%
k=np.array([[[4,40],[2,23],[3,33]],[[4,44],[2,20],[3,35]]])
k
# Out:
# array([[[ 4, 40],
#         [ 2, 23],
#         [ 3, 33]],
#
#        [[ 4, 44],
#         [ 2, 20],
#         [ 3, 35]]])

# %%
k=np.array([[[4,40],[2,23],[3,33]],[[4,44],[2,20],[3,35]],[[4,43],[2,23],[3,32]]])
k
# Out:
# array([[[ 4, 40],
#         [ 2, 23],
#         [ 3, 33]],
#
#        [[ 4, 44],
#         [ 2, 20],
#         [ 3, 35]],
#
#        [[ 4, 43],
#         [ 2, 23],
#         [ 3, 32]]])

# %%
k.shape
# Out:
# (3, 3, 2)

# %%
sp=np.array([[4,40,2],[3,34,2],[2,55,0],[2,20,9]])
sp
# Out:
# array([[ 4, 40,  2],
#        [ 3, 34,  2],
#        [ 2, 55,  0],
#        [ 2, 20,  9]])

# %%
sp[:-1,:]
# Out:
# array([[ 4, 40,  2],
#        [ 3, 34,  2],
#        [ 2, 55,  0]])

# %%
sp[2:]
# Out:
# array([[ 2, 55,  0],
#        [ 2, 20,  9]])

# %%
m=np.array([[4,40,2],[3,34,2],[2,55,0]])
m
# Out:
# array([[ 4, 40,  2],
#        [ 3, 34,  2],
#        [ 2, 55,  0]])

# %%
m[0:,0:]
# Out:
# array([[ 4, 40,  2],
#        [ 3, 34,  2],
#        [ 2, 55,  0]])

# %%
x=[3,2,1]
x+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 x=[3,2,1]
# ----> 2 x+5
#
# TypeError: can only concatenate list (not "int") to list

# %%
y=([1,2],[2,3])
y+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 y=([1,2],[2,3])
# ----> 2 y+5
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
kp=np.array([[3,8,4],[9,3,5],[11,15,17],[19,31,8]])
kp
# Out:
# array([[ 3,  8,  4],
#        [ 9,  3,  5],
#        [11, 15, 17],
#        [19, 31,  8]])

# %%
kp[0,:]=[30,40,50]
kp
# Out:
# array([[30, 40, 50],
#        [ 9,  3,  5],
#        [11, 15, 17],
#        [19, 31,  8]])

# %%
kp[:,1]=[22,34,4,5]
kp
# Out:
# array([[30, 22, 50],
#        [ 9, 34,  5],
#        [11,  4, 17],
#        [19,  5,  8]])

# %%
kp[:2,1:]=[[22,22],[21,44]]
kp
# Out:
# array([[30, 22, 22],
#        [ 9, 21, 44],
#        [11,  4, 17],
#        [19,  5,  8]])

# %%
np.append(kp,[[1,1,1]],axis=0)
# Out:
# array([[30, 22, 22],
#        [ 9, 21, 44],
#        [11,  4, 17],
#        [19,  5,  8],
#        [ 1,  1,  1]])

# %%
np.append(kp,[[1],[3],[4],[5]],axis=1)
# Out:
# array([[30, 22, 22,  1],
#        [ 9, 21, 44,  3],
#        [11,  4, 17,  4],
#        [19,  5,  8,  5]])

# %%
np.delete(kp,1,0)
# Out:
# array([[30, 22, 22],
#        [11,  4, 17],
#        [19,  5,  8]])

# %%
np.delete(kp,1,1)
# Out:
# array([[30, 22],
#        [ 9, 44],
#        [11, 17],
#        [19,  8]])

# %%
np.delete(kp,3,axis=0)
# Out:
# array([[30, 22, 22],
#        [ 9, 21, 44],
#        [11,  4, 17]])

# %%
kp.reshape(6,2)
# Out:
# array([[30, 22],
#        [22,  9],
#        [21, 44],
#        [11,  4],
#        [17, 19],
#        [ 5,  8]])

# %%
a1=np.array([3.4,3,4])
a1
# Out:
# array([3.4, 3. , 4. ])

# %%
a1.dtype
# Out:
# dtype('float64')

# %%
a1.astype('int16')
# Out:
# array([3, 3, 4], dtype=int16)

# %%
a1.astype(int)
# Out:
# array([3, 3, 4])

# %%
a1.sum()
# Out:
# 10.4

# %%
#np.array()
#np.ones
#np.zeros()
#np.arrange()
#np.linspace()
#np.random.randint(s)
